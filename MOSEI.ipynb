# %%
from constants import SDK_PATH, DATA_PATH, WORD_EMB_PATH, CACHE_PATH
import sys
import os
import requests
import numpy as np
from mmsdk import mmdatasdk as md

# Append the SDK path
if SDK_PATH is None:
    print("SDK path is not specified! Please specify first in constants/paths.py")
    exit(0)
else:
    sys.path.append(SDK_PATH)

# Create folder for storing data if it doesn't exist
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH, exist_ok=True)

# Helper function to download a file from a URL
def download_file(url, dest):
    try:
        print(f"Downloading from {url}...")
        response = requests.get(url, stream=True)
        response.raise_for_status()
        with open(dest, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Downloaded: {dest}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading {url}: {e}")

# Function to get the filename from the URL (last segment)
def get_filename_from_url(url):
    return url.split('/')[-1]  # Extract the last part of the URL

# Download function that iterates over dataset features
def download_dataset_features(feature_dict, feature_type):
    for feature_name, url in feature_dict.items():
        print(f"\nProcessing {feature_type} feature: {feature_name}")
        
        # Use the filename derived from the URL instead of the dictionary key
        filename = get_filename_from_url(url)
        dest_path = os.path.join(DATA_PATH, filename)

        if not os.path.exists(dest_path):
            download_file(url, dest_path)
        else:
            print(f"{feature_type} feature '{feature_name}' already downloaded at {dest_path}")

# Dataset initialization
DATASET = md.cmu_mosei

# Process high-level, raw, and label features
try:
    print("\nStarting download of high-level features...")
    download_dataset_features(DATASET.highlevel, "High-level")
except Exception as e:
    print(f"Error downloading high-level features: {e}")

try:
    print("\nStarting download of raw features...")
    download_dataset_features(DATASET.raw, "Raw")
except Exception as e:
    print(f"Error downloading raw features: {e}")

try:
    print("\nStarting download of labels...")
    download_dataset_features(DATASET.labels, "Label")
except Exception as e:
    print(f"Error downloading labels: {e}")
# Out:
# Starting download of high-level features...
#
# Processing High-level feature: glove_vectors
# High-level feature 'glove_vectors' already downloaded at ./data/CMU_MOSEI_TimestampedWordVectors.csd
#
# Processing High-level feature: COVAREP
# High-level feature 'COVAREP' already downloaded at ./data/CMU_MOSEI_COVAREP.csd
#
# Processing High-level feature: OpenFace_2
# High-level feature 'OpenFace_2' already downloaded at ./data/CMU_MOSEI_VisualOpenFace2.csd
#
# Processing High-level feature: FACET 4.2
# High-level feature 'FACET 4.2' already downloaded at ./data/CMU_MOSEI_VisualFacet42.csd
#
# Starting download of raw features...
#
# Processing Raw feature: words
# Raw feature 'words' already downloaded at ./data/CMU_MOSEI_TimestampedWords.csd
#
# Processing Raw feature: phones
# Raw feature 'phones' already downloaded at ./data/CMU_MOSEI_TimestampedPhones.csd
#
# Starting download of labels...
#
# Processing Label feature: All Labels
# Label feature 'All Labels' already downloaded at ./data/CMU_MOSEI_Labels.csd

# %%
# list the directory contents... let's see what features there are
data_files = os.listdir(DATA_PATH)
print('\n'.join(data_files))
# Out:
# CMU_MOSEI_COVAREP.csd
# CMU_MOSEI_Labels.csd
# CMU_MOSEI_TimestampedPhones.csd
# CMU_MOSEI_TimestampedWords.csd
# CMU_MOSEI_TimestampedWordVectors.csd
# CMU_MOSEI_VisualFacet42.csd
# CMU_MOSEI_VisualOpenFace2.csd

# %% [markdown]
# We have multiple files which can be broadly classified into three categories, highlevel, raw and labels.
#
# <strong>Highlevel</strong> contains the extracted features for each modality (e.g OpenFace facial landmarks, openSMILE acoustic features) while <strong>raw</strong> contains the raw transctripts, phonemes.
#
# We have multiple files with the .csd extension. This stands for <strong>computational sequences</strong>, which is the underlying data structure for all features in the SDK.
#
# <strong> Highlevel features: </strong>
# - CMU_MOSEI_VisualFacet42.csd (Video modality)
# - CMU_MOSEI_VisualOpenFace2.csd (Video Modality)
# - CMU_MOSEI_COVAREP.csd (Audio Modality)
# - CMU_MOSEI_TimestampedWordVectors.csd (Text Modality)

# %% [markdown]
# ## Loading the data

# %%
visual_field = 'CMU_MOSEI_VisualFacet42'
acoustic_field = 'CMU_MOSEI_COVAREP'
text_field = 'CMU_MOSEI_TimestampedWordVectors'

features = [
    text_field, 
    visual_field, 
    acoustic_field
]

recipe = {feat: os.path.join(DATA_PATH, feat) + '.csd' for feat in features}
dataset = md.mmdataset(recipe)
# Out:
# [2024-10-29 21:20:03.402] | Success | Computational sequence read from file ./data/CMU_MOSEI_TimestampedWordVectors.csd ...
# [2024-10-29 21:20:03.948] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2024-10-29 21:20:03.948] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2024-10-29 21:20:06.218] | Success | <glove_vectors> computational sequence data in correct format.
# [2024-10-29 21:20:06.228] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2024-10-29 21:20:06.228] | Warning | <glove_vectors> computational sequence does not have all the required metadata ... continuing
# [2024-10-29 21:20:06.228] | Success | Computational sequence read from file ./data/CMU_MOSEI_VisualFacet42.csd ...
# [2024-10-29 21:20:06.946] | Status  | Checking the integrity of the <FACET 4.2> computational sequence ...
# [2024-10-29 21:20:06.946] | Status  | Checking the format of the data in <FACET 4.2> computational sequence ...
# [2024-10-29 21:20:09.403] | Success | <FACET 4.2> computational sequence data in correct format.
# [2024-10-29 21:20:09.403] | Status  | Checking the format of the metadata in <FACET 4.2> computational sequence ...
# [2024-10-29 21:20:09.403] | Warning | <FACET 4.2> computational sequence does not have all the required metadata ... continuing
# [2024-10-29 21:20:09.411] | Success | Computational sequence read from file ./data/CMU_MOSEI_COVAREP.csd ...
# [2024-10-29 21:20:09.994] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2024-10-29 21:20:09.994] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2024-10-29 21:20:11.981] | Success | <COVAREP> computational sequence data in correct format.
# [2024-10-29 21:20:11.981] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2024-10-29 21:20:11.981] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2024-10-29 21:20:11.981] | Success | Dataset initialized successfully ...

# %% [markdown]
# To load the dataset, we need to tell the SDK which features we need and where they exist. Thus, we construct a dictionary with format {feature_name: csd_path} and feed it to mmdataset object in the SDK.
#
# From the highlevel features, VisualFacet is used for video modality since this file stores facial expression data extracted using the FACET tool. FACET analyzes microexpressions, including movements of facial muscles (like eyebrow raises or smiles) and emotional states (e.g., joy, anger). Thus, making it more suitable for emotion detection than openFace since it
# tracks facial landmarks, head poses, and eye gaze, offering detailed spatial and motion-related facial features across video frames.
#
# COVAREP is used for audio related features and TimeStampedWordVectors provides Pre-trained embeddings using GLoVe capture semantic relationships and contextual meaning between words.

# %%
print(list(dataset.keys()))
print("=" * 80)

print(list(dataset[visual_field].keys())[:10])
print("=" * 80)

some_id = list(dataset[visual_field].keys())[15]
print(list(dataset[visual_field][some_id].keys()))
print("=" * 80)

print(list(dataset[visual_field][some_id]['intervals'].shape))
print("=" * 80)

print(list(dataset[visual_field][some_id]['features'].shape))
print(list(dataset[text_field][some_id]['features'].shape))
print(list(dataset[acoustic_field][some_id]['features'].shape))
print("Different modalities have different number of time steps!")
# Out:
# ['CMU_MOSEI_TimestampedWordVectors', 'CMU_MOSEI_VisualFacet42', 'CMU_MOSEI_COVAREP']
# ================================================================================
# ['--qXJuDtHPw', '-3g5yACwYnA', '-3nNcZdcdvU', '-571d8cVauQ', '-6rXp3zJ3kc', '-9YyBTjo1zo', '-9y-fZ3swSY', '-AUZQgSxyPQ', '-Alixo7euuU', '-Eqdz5y4pEY']
# ================================================================================
# ['features', 'intervals']
# ================================================================================
# [3658, 2]
# ================================================================================
# [3658, 35]
# [321, 300]
# [12209, 74]
# Different modalities have different number of time steps!

# %%
# we define a simple averaging function that does not depend on intervals
def avg(intervals: np.array, features: np.array) -> np.array:
    try:
        return np.average(features, axis=0)
    except:
        return features

# first we align to words with averaging, collapse_function receives a list of functions
dataset.align(text_field, collapse_functions=[avg])
# Out:
# [2024-10-29 21:20:17.275] | Status  | Unify was called ...
# [2024-10-29 21:20:17.276] | Warning | PEBwwe0PLZ8 entry is not shared among all sequences, removing it ...
# [2024-10-29 21:20:17.280] | Success | Unify completed ...
# [2024-10-29 21:20:17.280] | Status  | Pre-alignment based on <CMU_MOSEI_TimestampedWordVectors> computational sequence started ...
# [2024-10-29 21:26:04.796] | Status  | Pre-alignment done for <CMU_MOSEI_COVAREP> ...
# [2024-10-29 21:28:13.500] | Status  | Pre-alignment done for <CMU_MOSEI_VisualFacet42> ...
# [2024-10-29 21:29:23.355] | Status  | Alignment starting ...
# Overall Progress:   0%|                                          | 0/3836 [00:00<?, ? Computational Sequence Entries/s]
#   0%|                                                                                   | 0/183 [00:00<?, ? Segments/s]
# Aligning --qXJuDtHPw:   0%|                                                             | 0/183 [00:00<?, ? Segments/s]
# Aligning --qXJuDtHPw:  19%|█████████▍                                         | 34/183 [00:00<00:00, 336.99 Segments/s]
# Aligning --qXJuDtHPw:  45%|███████████████████████▏                           | 83/183 [00:00<00:00, 421.87 Segments/s]
# Aligning --qXJuDtHPw:  72%|███████████████████████████████████▊              | 131/183 [00:00<00:00, 447.41 Segments/s]
# Aligning --qXJuDtHPw:  99%|█████████████████████████████████████████████████▋| 182/183 [00:00<00:00, 470.30 Segments/s]
# Overall Progress:   0%|                                  | 1/3836 [00:00<26:44,  2.39 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/435 [00:00<?, ? Segments/s]
# Aligning -3g5yACwYnA:   0%|                                                             | 0/435 [00:00<?, ? Segments/s]
# Aligning -3g5yACwYnA:   6%|██▉                                                | 25/435 [00:00<00:01, 243.77 Segments/s]
# Aligning -3g5yACwYnA:  12%|██████                                             | 52/435 [00:00<00:01, 253.56 Segments/s]
# Aligning -3g5yACwYnA:  18%|█████████▎                                         | 79/435 [00:00<00:01, 258.70 Segments/s]
# Aligning -3g5yACwYnA:  24%|████████████▏                                     | 106/435 [00:00<00:01, 262.22 Segments/s]
Computational Sequence Entries/s]
#   0%|                                                                                   | 0/225 [00:00<?, ? Segments/s]
# Aligning -6rXp3zJ3kc:   0%|                                                             | 0/225 [00:00<?, ? Segments/s]
# Aligning -6rXp3zJ3kc:  18%|█████████                                          | 40/225 [00:00<00:00, 388.50 Segments/s]
# Aligning -6rXp3zJ3kc:  39%|███████████████████▉                               | 88/225 [00:00<00:00, 417.63 Segments/s]
# Aligning -6rXp3zJ3kc:  60%|██████████████████████████████                    | 135/225 [00:00<00:00, 422.15 Segments/s]
# Aligning -6rXp3zJ3kc:  80%|████████████████████████████████████████          | 180/225 [00:00<00:00, 430.23 Segments/s]
# Aligning -6rXp3zJ3kc: 100%|█████████████████████████████████████████████████▊| 224/225 [00:00<00:00, 433.27 Segments/s]
# Overall Progress:   0%|                                  | 5/3836 [00:03<46:50,  1.36 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/135 [00:00<?, ? Segments/s]
# Aligning -9YyBTjo1zo:   0%|                                                             | 0/135 [00:00<?, ? Segments/s]
# Aligning -9YyBTjo1zo:   9%|████▌                                              | 12/135 [00:00<00:01, 111.02 Segments/s]
# Aligning -9YyBTjo1zo:  19%|█████████▍                                         | 25/135 [00:00<00:00, 121.03 Segments/s]
# Aligning -9YyBTjo1zo:  28%|██████████████▎                                    | 38/135 [00:00<00:00, 124.52 Segments/s]
# Aligning -9YyBTjo1zo:  39%|███████████████████▋                               | 52/135 [00:00<00:00, 129.58 Segments/s]
# Aligning -9YyBTjo1zo:  49%|████████████████████████▉                          | 66/135 [00:00<00:00, 133.13 Segments/s]
# Aligning -9YyBTjo1zo:  59%|██████████████████████████████▏                    | 80/135 [00:00<00:00, 131.50 Segments/s]
# Aligning -9YyBTjo1zo:  70%|███████████████████████████████████▌               | 94/135 [00:00<00:00, 133.95 Segments/s]
# Aligning -9YyBTjo1zo:  80%|████████████████████████████████████████          | 108/135 [00:00<00:00, 131.27 Segments/s]
# Aligning -9YyBTjo1zo:  90%|█████████████████████████████████████████████▏    | 122/135 [00:00<00:00, 128.52 Segments/s]
# Aligning -9YyBTjo1zo: 100%|██████████████████████████████████████████████████| 135/135 [00:01<00:00, 125.92 Segments/s]
# Overall Progress:   0%|                                  | 6/3836 [00:04<54:16,  1.18 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/210 [00:00<?, ? Segments/s]
# Aligning -9y-fZ3swSY:   0%|                                                             | 0/210 [00:00<?, ? Segments/s]
# Aligning -9y-fZ3swSY:  21%|██████████▉                                        | 45/210 [00:00<00:00, 430.94 Segments/s]
# Aligning -9y-fZ3swSY:  45%|███████████████████████                            | 95/210 [00:00<00:00, 469.17 Segments/s]
# Aligning -9y-fZ3swSY:  68%|█████████████████████████████████▊                | 142/210 [00:00<00:00, 427.48 Segments/s]
# Aligning -9y-fZ3swSY:  94%|██████████████████████████████████████████████▉   | 197/210 [00:00<00:00, 457.15 Segments/s]
# Overall Progress:   0%|                                  | 7/3836 [00:05<46:24,  1.38 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/113 [00:00<?, ? Segments/s]
# Aligning -AUZQgSxyPQ:   0%|                                                             | 0/113 [00:00<?, ? Segments/s]
# Aligning -AUZQgSxyPQ:  51%|██████████████████████████▏                        | 58/113 [00:00<00:00, 546.51 Segments/s]
# Aligning -AUZQgSxyPQ: 100%|██████████████████████████████████████████████████| 113/113 [00:00<00:00, 545.78 Segments/s]
# Overall Progress:   0%|                                  | 8/3836 [00:05<35:58,  1.77 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/982 [00:00<?, ? Segments/s]
# Aligning -Alixo7euuU:   0%|                                                             | 0/982 [00:00<?, ? Segments/s]
# Aligning -Alixo7euuU:   2%|▉                                                  | 18/982 [00:00<00:05, 170.39 Segments/s]
# Aligning -Alixo7euuU:   4%|█▉                                                 | 38/982 [00:00<00:05, 186.31 Segments/s]
# Aligning -Alixo7euuU:   6%|██▉                                                | 57/982 [00:00<00:04, 187.15 Segments/s]
# Aligning -Alixo7euuU:   8%|███▉                                               | 76/982 [00:00<00:04, 187.06 Segments/s]
# Aligning -Alixo7euuU:  10%|████▉                                              | 95/982 [00:00<00:05, 168.95 Segments/s]
# Aligning -Alixo7euuU:  12%|█████▊                                            | 113/982 [00:00<00:05, 160.17 Segments/s]
# Aligning -Alixo7euuU:  13%|██████▌                                           | 130/982 [00:00<00:05, 146.27 Segments/s]
# Aligning -Alixo7euuU:  15%|███████▍                                          | 145/982 [00:00<00:05, 145.76 Segments/s]
# Aligning -Alixo7euuU:  16%|████████▏                                         | 160/982 [00:01<00:06, 135.78 Segments/s]
# Aligning -Alixo7euuU:  18%|████████▊                                         | 174/982 [00:01<00:06, 129.14 Segments/s]
# Aligning -Alixo7euuU:  19%|█████████▌                                        | 188/982 [00:01<00:06, 124.13 Segments/s]
# Aligning -Alixo7euuU:  20%|██████████▏                                       | 201/982 [00:01<00:06, 122.23 Segments/s]
# Aligning -Alixo7euuU:  22%|██████████▉                                       | 214/982 [00:01<00:06, 122.64 Segments/s]
# Aligning -Alixo7euuU:  23%|███████████▌                                      | 227/982 [00:01<00:06, 120.26 Segments/s]
# Aligning -Alixo7euuU:  24%|████████████▏                                     | 240/982 [00:01<00:06, 119.69 Segments/s]
# Aligning -Alixo7euuU:  26%|████████████▊                                     | 252/982 [00:01<00:06, 117.11 Segments/s]
# Aligning -Alixo7euuU:  27%|█████████████▍                                    | 264/982 [00:01<00:06, 117.52 Segments/s]
# Aligning -Alixo7euuU:  28%|██████████████                                    | 276/982 [00:02<00:06, 112.73 Segments/s]
# Aligning -Alixo7euuU:  30%|██████████████▊                                   | 290/982 [00:02<00:05, 119.90 Segments/s]
# Aligning -Alixo7euuU:  31%|███████████████▍                                  | 303/982 [00:02<00:05, 115.16 Segments/s]
# Aligning -Alixo7euuU:  32%|████████████████                                  | 315/982 [00:02<00:05, 113.74 Segments/s]
# Aligning -Alixo7euuU:  33%|████████████████▋                                 | 327/982 [00:02<00:05, 110.60 Segments/s]
# Aligning -Alixo7euuU:  35%|█████████████████▎                                | 339/982 [00:02<00:05, 107.41 Segments/s]
# Aligning -Alixo7euuU:  36%|█████████████████▊                                | 350/982 [00:02<00:05, 106.23 Segments/s]
/ Computational Sequence Entries]
#   0%|                                                                                   | 0/261 [00:00<?, ? Segments/s]
# Aligning -HeZS2-Prhc:   0%|                                                             | 0/261 [00:00<?, ? Segments/s]
# Aligning -HeZS2-Prhc:  12%|██████▎                                            | 32/261 [00:00<00:00, 316.38 Segments/s]
# Aligning -HeZS2-Prhc:  26%|█████████████                                      | 67/261 [00:00<00:00, 333.68 Segments/s]
# Aligning -HeZS2-Prhc:  39%|███████████████████▌                              | 102/261 [00:00<00:00, 339.55 Segments/s]
# Aligning -HeZS2-Prhc:  52%|██████████████████████████                        | 136/261 [00:00<00:00, 339.57 Segments/s]
# Aligning -HeZS2-Prhc:  65%|████████████████████████████████▌                 | 170/261 [00:00<00:00, 338.28 Segments/s]
# Aligning -HeZS2-Prhc:  78%|███████████████████████████████████████           | 204/261 [00:00<00:00, 338.20 Segments/s]
# Aligning -HeZS2-Prhc:  92%|█████████████████████████████████████████████▊    | 239/261 [00:00<00:00, 341.35 Segments/s]
# Overall Progress:   0%|                               | 11/3836 [00:14<1:46:59,  1.68s/ Computational Sequence Entries]
#   0%|                                                                                   | 0/112 [00:00<?, ? Segments/s]
# Aligning -HvKLjmsO5U:   0%|                                                             | 0/112 [00:00<?, ? Segments/s]
# Aligning -HvKLjmsO5U:  59%|██████████████████████████████                     | 66/112 [00:00<00:00, 654.57 Segments/s]
# Overall Progress:   0%|                               | 12/3836 [00:14<1:17:57,  1.22s/ Computational Sequence Entries]
#   0%|                                                                                   | 0/160 [00:00<?, ? Segments/s]
# Aligning -HwX2H8Z4hY:   0%|                                                             | 0/160 [00:00<?, ? Segments/s]
# Aligning -HwX2H8Z4hY:  34%|█████████████████▏                                 | 54/160 [00:00<00:00, 498.38 Segments/s]
# Aligning -HwX2H8Z4hY:  65%|████████████████████████████████▌                 | 104/160 [00:00<00:00, 496.86 Segments/s]
# Aligning -HwX2H8Z4hY:  98%|█████████████████████████████████████████████████ | 157/160 [00:00<00:00, 501.19 Segments/s]
# Overall Progress:   0%|                               | 13/3836 [00:15<1:00:49,  1.05 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/510 [00:00<?, ? Segments/s]
# Aligning -IUUR2yyNbw:   0%|                                                             | 0/510 [00:00<?, ? Segments/s]
# Aligning -IUUR2yyNbw:   5%|██▋                                                | 27/510 [00:00<00:01, 247.40 Segments/s]
# Aligning -IUUR2yyNbw:  10%|█████▏                                             | 52/510 [00:00<00:01, 246.79 Segments/s]
# Aligning -IUUR2yyNbw:  15%|███████▋                                           | 77/510 [00:00<00:01, 238.41 Segments/s]
# Aligning -IUUR2yyNbw:  20%|██████████                                        | 102/510 [00:00<00:01, 242.49 Segments/s]
# Aligning -IUUR2yyNbw:  25%|████████████▍                                     | 127/510 [00:00<00:01, 245.12 Segments/s]
# Aligning -IUUR2yyNbw:  30%|███████████████                                   | 153/510 [00:00<00:01, 248.69 Segments/s]
# Aligning -IUUR2yyNbw:  35%|█████████████████▍                                | 178/510 [00:00<00:01, 248.73 Segments/s]
# Aligning -IUUR2yyNbw:  40%|███████████████████▉                              | 203/510 [00:00<00:01, 248.39 Segments/s]
# Aligning -IUUR2yyNbw:  45%|██████████████████████▎                           | 228/510 [00:00<00:01, 248.11 Segments/s]
# Aligning -IUUR2yyNbw:  50%|████████████████████████▉                         | 254/510 [00:01<00:01, 250.45 Segments/s]
# Aligning -IUUR2yyNbw:  55%|███████████████████████████▍                      | 280/510 [00:01<00:00, 244.63 Segments/s]
# Aligning -IUUR2yyNbw:  60%|█████████████████████████████▉                    | 305/510 [00:01<00:00, 243.44 Segments/s]
# Aligning -IUUR2yyNbw:  65%|████████████████████████████████▎                 | 330/510 [00:01<00:00, 243.98 Segments/s]
# Aligning -IUUR2yyNbw:  70%|██████████████████████████████████▊               | 355/510 [00:01<00:00, 245.34 Segments/s]
# Aligning -IUUR2yyNbw:  75%|█████████████████████████████████████▎            | 380/510 [00:01<00:00, 246.59 Segments/s]
# Aligning -IUUR2yyNbw:  80%|███████████████████████████████████████▊          | 406/510 [00:01<00:00, 250.04 Segments/s]
# Aligning -IUUR2yyNbw:  85%|██████████████████████████████████████████▎       | 432/510 [00:01<00:00, 248.04 Segments/s]
# Aligning -IUUR2yyNbw:  90%|████████████████████████████████████████████▉     | 458/510 [00:01<00:00, 250.03 Segments/s]
# Aligning -IUUR2yyNbw:  95%|███████████████████████████████████████████████▍  | 484/510 [00:01<00:00, 246.57 Segments/s]
# Aligning -IUUR2yyNbw: 100%|█████████████████████████████████████████████████▉| 509/510 [00:02<00:00, 244.05 Segments/s]
# Overall Progress:   0%|                               | 14/3836 [00:17<1:22:26,  1.29s/ Computational Sequence Entries]
#   0%|                                                                                   | 0/150 [00:00<?, ? Segments/s]
# Aligning -I_e4mIh0yE:   0%|                                                             | 0/150 [00:00<?, ? Segments/s]
# Aligning -I_e4mIh0yE:  36%|██████████████████▎                                | 54/150 [00:00<00:00, 535.43 Segments/s]
# Aligning -I_e4mIh0yE:  74%|█████████████████████████████████████             | 111/150 [00:00<00:00, 549.61 Segments/s]
# Overall Progress:   0%|                               | 15/3836 [00:17<1:02:55,  1.01 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/321 [00:00<?, ? Segments/s]
# Aligning -IqSFQePnpU:   0%|                                                             | 0/321 [00:00<?, ? Segments/s]
# Aligning -IqSFQePnpU:   8%|████▎                                              | 27/321 [00:00<00:01, 263.15 Segments/s]
# Aligning -IqSFQePnpU:  18%|█████████▏                                         | 58/321 [00:00<00:00, 284.10 Segments/s]
# Aligning -IqSFQePnpU:  27%|█████████████▊                                     | 87/321 [00:00<00:00, 284.73 Segments/s]
# Aligning -IqSFQePnpU:  36%|██████████████████▏                               | 117/321 [00:00<00:00, 290.39 Segments/s]
# Aligning -IqSFQePnpU:  46%|██████████████████████▉                           | 147/321 [00:00<00:00, 290.27 Segments/s]
# Aligning -IqSFQePnpU:  55%|███████████████████████████▌                      | 177/321 [00:00<00:00, 288.71 Segments/s]
# Aligning -IqSFQePnpU:  64%|████████████████████████████████                  | 206/321 [00:00<00:00, 278.67 Segments/s]
# Aligning -IqSFQePnpU:  73%|████████████████████████████████████▍             | 234/321 [00:00<00:00, 270.97 Segments/s]
# Aligning -IqSFQePnpU:  82%|█████████████████████████████████████████         | 264/321 [00:00<00:00, 278.97 Segments/s]
# Aligning -IqSFQePnpU:  92%|█████████████████████████████████████████████▊    | 294/321 [00:01<00:00, 285.18 Segments/s]
# Overall Progress:   0%|▏                              | 16/3836 [00:18<1:05:44,  1.03s/ Computational Sequence Entries]
#   0%|                                                                                   | 0
# Aligning -LnuDPiuuZw:  82%|█████████████████████████████████████████▏        | 308/374 [00:01<00:00, 271.78 Segments/s]
# Aligning -LnuDPiuuZw:  90%|████████████████████████████████████████████▉     | 336/374 [00:01<00:00, 271.70 Segments/s]
# Aligning -LnuDPiuuZw:  97%|████████████████████████████████████████████████▋ | 364/374 [00:01<00:00, 269.03 Segments/s]
# Overall Progress:   0%|▏                              | 18/3836 [00:21<1:16:24,  1.20s/ Computational Sequence Entries]
#   0%|                                                                                   | 0/257 [00:00<?, ? Segments/s]
# Aligning -MeTTeMJBNc:   0%|                                                             | 0/257 [00:00<?, ? Segments/s]
# Aligning -MeTTeMJBNc:  14%|███████▎                                           | 37/257 [00:00<00:00, 361.12 Segments/s]
# Aligning -MeTTeMJBNc:  29%|██████████████▉                                    | 75/257 [00:00<00:00, 368.32 Segments/s]
# Aligning -MeTTeMJBNc:  44%|██████████████████████▏                           | 114/257 [00:00<00:00, 374.97 Segments/s]
# Aligning -MeTTeMJBNc:  60%|█████████████████████████████▊                    | 153/257 [00:00<00:00, 378.80 Segments/s]
# Aligning -MeTTeMJBNc:  74%|█████████████████████████████████████▏            | 191/257 [00:00<00:00, 373.76 Segments/s]
# Aligning -MeTTeMJBNc:  89%|████████████████████████████████████████████▌     | 229/257 [00:00<00:00, 374.12 Segments/s]
# Overall Progress:   0%|▏                              | 19/3836 [00:22<1:06:38,  1.05s/ Computational Sequence Entries]
#   0%|                                                                                   | 0/148 [00:00<?, ? Segments/s]
# Aligning -NFrJFQijFE:   0%|                                                             | 0/148 [00:00<?, ? Segments/s]
# Aligning -NFrJFQijFE:   6%|███▏                                                 | 9/148 [00:00<00:01, 83.83 Segments/s]
# Aligning -NFrJFQijFE:  14%|███████                                             | 20/148 [00:00<00:01, 98.52 Segments/s]
# Aligning -NFrJFQijFE:  22%|███████████                                        | 32/148 [00:00<00:01, 105.67 Segments/s]
# Aligning -NFrJFQijFE:  30%|███████████████▏                                   | 44/148 [00:00<00:00, 109.71 Segments/s]
# Aligning -NFrJFQijFE:  39%|███████████████████▋                               | 57/148 [00:00<00:00, 114.85 Segments/s]
# Aligning -NFrJFQijFE:  47%|███████████████████████▊                           | 69/148 [00:00<00:00, 115.62 Segments/s]
# Aligning -NFrJFQijFE:  55%|███████████████████████████▉                       | 81/148 [00:00<00:00, 115.60 Segments/s]
# Aligning -NFrJFQijFE:  63%|████████████████████████████████                   | 93/148 [00:00<00:00, 116.61 Segments/s]
# Aligning -NFrJFQijFE:  71%|███████████████████████████████████▍              | 105/148 [00:00<00:00, 114.09 Segments/s]
# Aligning -NFrJFQijFE:  80%|███████████████████████████████████████▊          | 118/148 [00:01<00:00, 114.66 Segments/s]
# Aligning -NFrJFQijFE:  88%|███████████████████████████████████████████▉      | 130/148 [00:01<00:00, 112.68 Segments/s]
# Aligning -NFrJFQijFE:  96%|███████████████████████████████████████████████▉  | 142/148 [00:01<00:00, 114.08 Segments/s]
# Overall Progress:   1%|▏                              | 20/3836 [00:23<1:12:00,  1.13s/ Computational Sequence Entries]
#   0%|                                                                                   | 0
Computational Sequence Entries/s]
#   0%|                                                                                   | 0/205 [00:00<?, ? Segments/s]
# Aligning -UuX1xuaiiE:   0%|                                                             | 0/205 [00:00<?, ? Segments/s]
# Aligning -UuX1xuaiiE:  20%|█████████▉                                         | 40/205 [00:00<00:00, 396.86 Segments/s]
# Aligning -UuX1xuaiiE:  44%|██████████████████████▍                            | 90/205 [00:00<00:00, 455.45 Segments/s]
# Aligning -UuX1xuaiiE:  68%|█████████████████████████████████▉                | 139/205 [00:00<00:00, 468.63 Segments/s]
# Aligning -UuX1xuaiiE:  92%|██████████████████████████████████████████████    | 189/205 [00:00<00:00, 477.80 Segments/s]
# Overall Progress:   1%|▏                                | 27/3836 [00:28<46:12,  1.37 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/121 [00:00<?, ? Segments/s]
# Aligning -VmheDA92mM:   0%|                                                             | 0/121 [00:00<?, ? Segments/s]
# Aligning -VmheDA92mM:  10%|█████                                              | 12/121 [00:00<00:00, 116.73 Segments/s]
# Aligning -VmheDA92mM:  21%|██████████▌                                        | 25/121 [00:00<00:00, 121.61 Segments/s]
# Aligning -VmheDA92mM:  31%|████████████████                                   | 38/121 [00:00<00:00, 124.18 Segments/s]
# Aligning -VmheDA92mM:  43%|█████████████████████▉                             | 52/121 [00:00<00:00, 127.15 Segments/s]
# Aligning -VmheDA92mM:  55%|███████████████████████████▊                       | 66/121 [00:00<00:00, 128.90 Segments/s]
# Aligning -VmheDA92mM:  65%|█████████████████████████████████▎                 | 79/121 [00:00<00:00, 126.77 Segments/s]
# Aligning -VmheDA92mM:  76%|██████████████████████████████████████▊            | 92/121 [00:00<00:00, 127.09 Segments/s]
# Aligning -VmheDA92mM:  87%|███████████████████████████████████████████▍      | 105/121 [00:00<00:00, 125.33 Segments/s]
# Aligning -VmheDA92mM:  98%|████████████████████████████████████████████████▊ | 118/121 [00:00<00:00, 125.85 Segments/s]
# Overall Progress:   1%|▏                                | 28/3836 [00:29<50:50,  1.25 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/201 [00:00<?, ? Segments/s]
# Aligning -WXXTNIJcVM:   0%|                                                             | 0/201 [00:00<?, ? Segments/s]
# Aligning -WXXTNIJcVM:  25%|████████████▋                                      | 50/201 [00:00<00:00, 499.93 Segments/s]
# Aligning -WXXTNIJcVM:  50%|█████████████████████████                         | 101/201 [00:00<00:00, 500.61 Segments/s]
# Aligning -WXXTNIJcVM:  76%|█████████████████████████████████████▊            | 152/201 [00:00<00:00, 495.66 Segments/s]
# Overall Progress:   1%|▏                                | 29/3836 [00:29<43:39,  1.45 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/256 [00:00<?, ? Segments/s]
# Aligning -ZgjBOA1Yhw:   0%|                                                             | 0/256 [00:00<?, ? Segments/s]
# Aligning -ZgjBOA1Yhw:  16%|███████▉                                           | 40/256 [00:00<00:00, 395.47 Segments/s]
# Aligning -ZgjBOA1Yhw:  32%|████████████████▏                                  | 81/256 [00:00<00:00, 400.07 Segments/s]
# Aligning -ZgjBOA1Yhw:  48%|███████████████████████▊                          | 122/256 [00:00<00:00, 404.26 Segments/s]
# Aligning -ZgjBOA1Yhw:  64%|████████████████████████████████                  | 164/256 [00:00<00:00, 408.18 Segments/s]
# Aligning -ZgjBOA1Yhw:  80%|████████████████████████████████████████          | 205/256 [00:00<00:00, 401.29 Segments/s]
# Aligning -ZgjBOA1Yhw:  96%|████████████████████████████████████████████████▏ | 247/256 [00:00<00:00, 407.03 Segments/s]
# Overall Progress:   1%|▎                                | 30/3836 [00:30<42:41,  1.49 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/241 [00:00<?, ? Segments/s]
# Aligning -a55Q6RWvTA:   0%|                                                             | 0/241 [00:00<?, ? Segments/s]
# Aligning -a55Q6RWvTA:  17%|████████▉                                          | 42/241 [00:00<00:00, 414.93 Segments/s]
# Aligning -a55Q6RWvTA:  36%|██████████████████▏                                | 86/241 [00:00<00:00, 425.99 Segments/s]
# Aligning -a55Q6RWvTA:  54%|██████████████████████████▊                       | 129/241 [00:00<00:00, 423.98 Segments/s]
# Aligning -a55Q6RWvTA:  71%|███████████████████████████████████▋              | 172/241 [00:00<00:00, 422.16 Segments/s]
# Aligning -a55Q6RWvTA:  89%|████████████████████████████████████████████▌     | 215/241 [00:00<00:00, 424.34 Segments/s]
# Overall Progress:   1%|▎                                | 31/3836 [00:31<40:49,  1.55 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/175 [00:00<?, ? Segments/s]
# Aligning -aNfi7CP8vM:   0%|                                                             | 0/175 [00:00<?, ? Segments/s]
# Aligning -aNfi7CP8vM:  28%|██████████████▎                                    | 49/175 [00:00<00:00, 465.90 Segments/s]
# Aligning -aNfi7CP8vM:  55%|███████████████████████████▉                       | 96/175 [00:00<00:00, 468.12 Segments/s]
# Aligning -aNfi7CP8vM:  82%|████████████████████████████████████████▊         | 143/175 [00:00<00:00, 460.02 Segments/s]
# Overall Progress:   1%|▎                                | 32/3836 [00:31<36:10,  1.75 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/126 [00:00<?, ? Segments/s]
# Aligning -aqamKhZ1Ec:   0%|                                                             | 0/126 [00:00<?, ? Segments/s]
# Aligning -aqamKhZ1Ec:  49%|█████████████████████████                          | 62/126 [00:00<00:00, 605.72 Segments/s]
# Aligning -aqamKhZ1Ec:  98%|████████████████████████████████████████████████▊ | 123/126 [00:00<00:00, 607.12 Segments/s]
# Overall Progress:   1%|▎                                | 33/3836 [00:31<29:26,  2.15 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/430 [00:00<?, ? Segments/s]
# Aligning -bl5PfNIYrk:   0%|                                                             | 0/430 [00:00<?, ? Segments/s]
# Aligning -bl5PfNIYrk:   6%|██▊                                                | 24/430 [00:00<00:01, 237.10 Segments/s]
# Aligning -bl5PfNIYrk:  12%|██████                                             | 51/430 [00:00<00:01, 253.78 Segments/s]
# Aligning -bl5PfNIYrk:  18%|█████████▏                                         | 77/430 [00:00<00:01, 251.98 Segments/s]
# Aligning -bl5PfNIYrk:  24%|███████████▉                                      | 103/430 [00:00<00:01, 249.99 Segments/s]
# Aligning -bl5PfNIYrk:  30%|███████████████                                   | 129/430 [00:00<00:01, 249.50 Segments/s]
# Aligning -bl5PfNIYrk:  36%|██████████████████                                | 155/430 [00:00<00:01, 252.18 Segments/s]
# Aligning -bl5PfNIYrk:  42%|█████████████████████                             | 181/430 [00:00<00:01, 245.19 Segments/s]
# Aligning -bl5PfNIYrk:  48%|███████████████████████▉                          | 206/430 [00:00<00:00, 240.07 Segments/s]
# ...
#   0%|                                                                                   | 0/282 [00:00<?, ? Segments/s]
# Aligning 112631:   0%|                                                                  | 0/282 [00:00<?, ? Segments/s]
# Aligning 112631:  16%|████████▉                                               | 45/282 [00:00<00:00, 446.05 Segments/s]
# Aligning 112631:  33%|██████████████████▎                                     | 92/282 [00:00<00:00, 455.08 Segments/s]
# Aligning 112631:  49%|███████████████████████████                            | 139/282 [00:00<00:00, 458.44 Segments/s]
# Aligning 112631:  66%|████████████████████████████████████▎                  | 186/282 [00:00<00:00, 462.27 Segments/s]
# Aligning 112631:  83%|█████████████████████████████████████████████▍         | 233/282 [00:00<00:00, 464.27 Segments/s]
# Aligning 112631:  99%|██████████████████████████████████████████████████████▌| 280/282 [00:00<00:00, 464.60 Segments/s]
# Overall Progress:   5%|█▌                              | 182/3836 [02:42<37:40,  1.62 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/225 [00:00<?, ? Segments/s]
# Aligning 112674:   0%|                                                                  | 0/225 [00:00<?, ? Segments/s]
# Aligning 112674:  23%|████████████▉                                           | 52/225 [00:00<00:00, 511.23 Segments/s]
# Aligning 112674:  46%|█████████████████████████▍                             | 104/225 [00:00<00:00, 511.65 Segments/s]
# Aligning 112674:  69%|██████████████████████████████████████▏                | 156/225 [00:00<00:00, 510.96 Segments/s]
# Aligning 112674:  93%|███████████████████████████████████████████████████    | 209/225 [00:00<00:00, 515.49 Segments/s]
# Overall Progress:   5%|█▌                              | 183/3836 [02:42<34:27,  1.77 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/258 [00:00<?, ? Segments/s]
# Aligning 112903:   0%|                                                                  | 0/258 [00:00<?, ? Segments/s]
# Aligning 112903:  17%|█████████▊                                              | 45/258 [00:00<00:00, 441.04 Segments/s]
# Aligning 112903:  36%|███████████████████▉                                    | 92/258 [00:00<00:00, 456.21 Segments/s]
# Aligning 112903:  53%|█████████████████████████████▍                         | 138/258 [00:00<00:00, 454.22 Segments/s]
# Aligning 112903:  72%|███████████████████████████████████████▍               | 185/258 [00:00<00:00, 456.85 Segments/s]
# Aligning 112903:  90%|█████████████████████████████████████████████████▋     | 233/258 [00:00<00:00, 458.67 Segments/s]
# Overall Progress:   5%|█▌                              | 184/3836 [02:43<34:23,  1.77 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/425 [00:00<?, ? Segments/s]
# Aligning 113162:   0%|                                                                  | 0/425 [00:00<?, ? Segments/s]
# Aligning 113162:   7%|███▊                                                    | 29/425 [00:00<00:01, 284.61 Segments/s]
# Aligning 113162:  14%|███████▊                                                | 59/425 [00:00<00:01, 289.96 Segments/s]
# Aligning 113162:  21%|███████████▋                                            | 89/425 [00:00<00:01, 292.61 Segments/s]
# Aligning 113162:  28%|███████████████▌                                       | 120/425 [00:00<00:01, 298.32 Segments/s]
# Aligning 113162:  35%|███████████████████▍                                   | 150/425 [00:00<00:00, 296.78 Segments/s]
# Aligning 113162:  43%|███████████████████████▋                               | 183/425 [00:00<00:00, 297.84 Segments/s]
# Aligning 113162:  50%|███████████████████████████▌                           | 213/425 [00:00<00:00, 297.25 Segments/s]
# Aligning 113162:  57%|███████████████████████████████▌                       | 244/425 [00:00<00:00, 300.88 Segments/s]
# Aligning 113162:  65%|███████████████████████████████████▌                   | 275/425 [00:00<00:00, 303.31 Segments/s]
# Aligning 113162:  72%|███████████████████████████████████████▌               | 306/425 [00:01<00:00, 301.74 Segments/s]
# Aligning 113162:  79%|███████████████████████████████████████████▌           | 337/425 [00:01<00:00, 296.97 Segments/s]
# Aligning 113162:  87%|███████████████████████████████████████████████▌       | 368/425 [00:01<00:00, 299.19 Segments/s]
# Aligning 113162:  94%|███████████████████████████████████████████████████▌   | 398/425 [00:01<00:00, 289.47 Segments/s]
# Overall Progress:   5%|█▌                              | 185/3836 [02:44<50:29,  1.21 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/297 [00:00<?, ? Segments/s]
# Aligning 113265:   0%|                                                                  | 0/297 [00:00<?, ? Segments/s]
# Aligning 113265:  12%|██████▊                                                 | 36/297 [00:00<00:00, 358.07 Segments/s]
# Aligning 113265:  26%|██████████████▎                                         | 76/297 [00:00<00:00, 381.44 Segments/s]
# Aligning 113265:  39%|█████████████████████▋                                 | 117/297 [00:00<00:00, 390.87 Segments/s]
# Aligning 113265:  53%|█████████████████████████████▎                         | 158/297 [00:00<00:00, 395.15 Segments/s]
# Aligning 113265:  67%|████████████████████████████████████▊                  | 199/297 [00:00<00:00, 396.90 Segments/s]
# Aligning 113265:  80%|████████████████████████████████████████████▎          | 239/297 [00:00<00:00, 395.28 Segments/s]
# Aligning 113265:  94%|███████████████████████████████████████████████████▊   | 280/297 [00:00<00:00, 398.48 Segments/s]
# Overall Progress:   5%|█▌                              | 186/3836 [02:45<49:09,  1.24 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/283 [00:00<?, ? Segments/s]
# Aligning 113369:   0%|                                                                  | 0/283 [00:00<?, ? Segments/s]
# Aligning 113369:  14%|███████▉                                                | 40/283 [00:00<00:00, 399.57 Segments/s]
# Aligning 113369:  29%|████████████████                                        | 81/283 [00:00<00:00, 403.94 Segments/s]
# Aligning 113369:  43%|███████████████████████▉                               | 123/283 [00:00<00:00, 407.62 Segments/s]
# Aligning 113369:  58%|███████████████████████████████▊                       | 164/283 [00:00<00:00, 404.63 Segments/s]
# Aligning 113369:  72%|███████████████████████████████████████▊               | 205/283 [00:00<00:00, 405.50 Segments/s]
# Aligning 113369:  87%|███████████████████████████████████████████████▊       | 246/283 [00:00<00:00, 405.90 Segments/s]
# Overall Progress:   5%|█▌                              | 187/3836 [02:46<47:14,  1.29 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/222 [00:00<?, ? Segments/s]
# Aligning 113491:   0%|                                                                  | 0/222 [00:00<?, ? Segments/s]
# Aligning 113491:  21%|███████████▊                                            | 47/222 [00:00<00:00, 465.02 Segments/s]
# Aligning 113491:  43%|████████████████████████▏                               | 96/222 [00:00<00:00, 475.30 Segments/s]
# Aligning 113491:  65%|███████████████████████████████████▋                   | 144/222 [00:00<00:00, 474.09 Segments/s]
# Aligning 113491:  86%|███████████████████████████████████████████████▌       | 192/222 [00:00<00:00, 472.49 Segments/s]
# Overall Progress:   5%|█▌                              | 188/3836 [02:46<41:43,  1.46 Computational Sequence Entries/s]
#   0%|                                                                                   | 0
# Aligning 114845:  56%|██████████████████████████████▌                        | 186/335 [00:00<00:00, 461.73 Segments/s]
# Aligning 114845:  70%|██████████████████████████████████████▎                | 233/335 [00:00<00:00, 457.83 Segments/s]
# Aligning 114845:  84%|█████████████████████████████████████████████▉         | 280/335 [00:00<00:00, 461.10 Segments/s]
# Aligning 114845:  98%|█████████████████████████████████████████████████████▋ | 327/335 [00:00<00:00, 462.05 Segments/s]
# Overall Progress:   5%|█▌                              | 193/3836 [02:49<36:29,  1.66 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/282 [00:00<?, ? Segments/s]
# Aligning 114945:   0%|                                                                  | 0/282 [00:00<?, ? Segments/s]
# Aligning 114945:  16%|█████████▏                                              | 46/282 [00:00<00:00, 453.70 Segments/s]
# Aligning 114945:  33%|██████████████████▎                                     | 92/282 [00:00<00:00, 455.68 Segments/s]
# Aligning 114945:  49%|███████████████████████████                            | 139/282 [00:00<00:00, 461.98 Segments/s]
# Aligning 114945:  66%|████████████████████████████████████▎                  | 186/282 [00:00<00:00, 462.31 Segments/s]
# Aligning 114945:  83%|█████████████████████████████████████████████▍         | 233/282 [00:00<00:00, 459.63 Segments/s]
# Aligning 114945:  99%|██████████████████████████████████████████████████████▌| 280/282 [00:00<00:00, 462.59 Segments/s]
# Overall Progress:   5%|█▌                              | 194/3836 [02:50<36:49,  1.65 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/209 [00:00<?, ? Segments/s]
# Aligning 115134:   0%|                                                                  | 0/209 [00:00<?, ? Segments/s]
# Aligning 115134:  24%|█████████████▋                                          | 51/209 [00:00<00:00, 502.08 Segments/s]
# Aligning 115134:  49%|███████████████████████████                            | 103/209 [00:00<00:00, 506.86 Segments/s]
# Aligning 115134:  74%|████████████████████████████████████████▌              | 154/209 [00:00<00:00, 505.90 Segments/s]
# Aligning 115134:  99%|██████████████████████████████████████████████████████▏| 206/209 [00:00<00:00, 508.38 Segments/s]
# Overall Progress:   5%|█▋                              | 195/3836 [02:50<33:25,  1.82 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/260 [00:00<?, ? Segments/s]
# Aligning 116202:   0%|                                                                  | 0/260 [00:00<?, ? Segments/s]
# Aligning 116202:  19%|██████████▌                                             | 49/260 [00:00<00:00, 483.62 Segments/s]
# Aligning 116202:  38%|█████████████████████▎                                  | 99/260 [00:00<00:00, 488.26 Segments/s]
# Aligning 116202:  57%|███████████████████████████████▎                       | 148/260 [00:00<00:00, 483.76 Segments/s]
# Aligning 116202:  76%|█████████████████████████████████████████▋             | 197/260 [00:00<00:00, 483.79 Segments/s]
# Aligning 116202:  95%|████████████████████████████████████████████████████   | 246/260 [00:00<00:00, 483.28 Segments/s]
# Overall Progress:   5%|█▋                              | 196/3836 [02:51<33:16,  1.82 Computational Sequence Entries/s]
#   0%|                                                                                   | 0/294 [00:00<?, ? Segments/s]
# Aligning 116213:   0%|                                                                  | 0/294 [00:00<?, ? Segments/s]
# Aligning 116213:  16%|████████▊                                               | 46/294 [00:00<00:00, 448.65 Segments/s]
# Aligning 116213:  31%|█████████████████▌                                      | 92/294 [00:00<00:00, 449.95 Segments/s]
